# %% [markdown]
# **TRABAJO 3**

# %% [markdown]
# **SONIA GARCÍA LORENZANA Y CRISTINA ACÍN COELLO DE PORTUGAL**

# %%
#Importamos todas las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Obtenemos el fichero de datos de nuestro trabajo (3)
trabajo3 = pd.read_csv("../../Trabajo 3 Info/trabajo3.csv")
trabajo3.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00    205.788017             0.083333
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
# 6                  688.38      0.000000             1.000000
# 7                  436.20      0.000000             1.000000
# 8                  200.00      0.000000             0.333333
# 9                    0.00      0.000000             0.166667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
# 6                    1.000000                          1.000000
# 7                    0.000000                          1.000000
# 8                    0.083333                          0.250000
# 9                    0.166667                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
# 5                0.000000                 0              8        1800.0
# 6                0.000000                 0             64       13500.0
# 7                0.000000                 0             12        2300.0
# 8                0.000000                 0              5        7000.0
# 9                0.000000                 0              3       11000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12
# 5  1400.057770       2407.246035          0.000000      12
# 6  6354.314328        198.065894          1.000000      12
# 7   679.065082        532.033990          0.000000      12
# 8   688.278568        311.963409          0.000000      12
# 9  1164.770591        100.302262          0.000000      12

# %%
trabajo3.count()
# Out:
# CUST_ID                             8950
# BALANCE                             8950
# BALANCE_FREQUENCY                   8950
# PURCHASES                           8950
# ONEOFF_PURCHASES                    8950
# INSTALLMENTS_PURCHASES              8950
# CASH_ADVANCE                        8950
# PURCHASES_FREQUENCY                 8950
# ONEOFF_PURCHASES_FREQUENCY          8950
# PURCHASES_INSTALLMENTS_FREQUENCY    8950
# CASH_ADVANCE_FREQUENCY              8950
# CASH_ADVANCE_TRX                    8950
# PURCHASES_TRX                       8950
# CREDIT_LIMIT                        8949
# PAYMENTS                            8950
# MINIMUM_PAYMENTS                    8637
# PRC_FULL_PAYMENT                    8950
# TENURE                              8950
# dtype: int64

# %%
#Vemos que hay algunas columnas que contienen NAs
trabajo3["MINIMUM_PAYMENTS"].count()
# Out:
# 8637

# %%
trabajo3["CREDIT_LIMIT"].count()
# Out:
# 8949

# %%
trabajo3.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#Es por ello que para trabajar mejor directamente eliminamos las filas que contengan algún NA
df=trabajo3.dropna()
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00                 0              2        1000.0
# 1                    0.25                 4              0        7000.0
# 2                    0.00                 0             12        7500.0
# 4                    0.00                 0              1        1200.0
# 5                    0.00                 0              8        1800.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 4   678.334763        244.791237          0.000000      12
# 5  1400.057770       2407.246035          0.000000      12

# %%
df.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.count()
# Out:
# CUST_ID                             8636
# BALANCE                             8636
# BALANCE_FREQUENCY                   8636
# PURCHASES                           8636
# ONEOFF_PURCHASES                    8636
# INSTALLMENTS_PURCHASES              8636
# CASH_ADVANCE                        8636
# PURCHASES_FREQUENCY                 8636
# ONEOFF_PURCHASES_FREQUENCY          8636
# PURCHASES_INSTALLMENTS_FREQUENCY    8636
# CASH_ADVANCE_FREQUENCY              8636
# CASH_ADVANCE_TRX                    8636
# PURCHASES_TRX                       8636
# CREDIT_LIMIT                        8636
# PAYMENTS                            8636
# MINIMUM_PAYMENTS                    8636
# PRC_FULL_PAYMENT                    8636
# TENURE                              8636
# dtype: int64

# %%
df.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %% [markdown]
# ***ANÁLISIS EXPLORATORIO***

# %% [markdown]
# En primer lugar vamos a comprobar si los clientes están repetidos en el dataset (CUST_ID) o sin embargo cada fila representa a una persona.

# %%
df["CUST_ID"].unique()
# Out:
# array(['C10001', 'C10002', 'C10003', ..., 'C19188', 'C19189', 'C19190'],
#       dtype=object)

# %%
df.groupby('CUST_ID').mean().count()
# Out:
# BALANCE                             8636
# BALANCE_FREQUENCY                   8636
# PURCHASES                           8636
# ONEOFF_PURCHASES                    8636
# INSTALLMENTS_PURCHASES              8636
# CASH_ADVANCE                        8636
# PURCHASES_FREQUENCY                 8636
# ONEOFF_PURCHASES_FREQUENCY          8636
# PURCHASES_INSTALLMENTS_FREQUENCY    8636
# CASH_ADVANCE_FREQUENCY              8636
# CASH_ADVANCE_TRX                    8636
# PURCHASES_TRX                       8636
# CREDIT_LIMIT                        8636
# PAYMENTS                            8636
# MINIMUM_PAYMENTS                    8636
# PRC_FULL_PAYMENT                    8636
# TENURE                              8636
# dtype: int64

# %% [markdown]
# Comprobamos que cada fila corresponde a un único cliente, no están repetidos. En total hay 8636 clientes.

# %% [markdown]
# **MATRIZ DE CORRELACIÓN**

# %% [markdown]
# Realizamos una matriz de correlación entre todas las variables del dataset.

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision

#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_a430a_row3_col2{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_a430a_row3_col4,#T_a430a_row15_col8{
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }#T_a430a_row3_col5,#T_a430a_row7_col9,#T_a430a_row8_col14,#T_a430a_row9_col13{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_a430a_row3_col6{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_a430a_row3_col7,#T_a430a_row4_col6{
#             background-color:  #eed0c0;
#             color:  #000000;
#         }#T_a430a_row3_col8,#T_a430a_row14_col9{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_a430a_row3_col11,#T_a430a_row7_col11{
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }#T_a430a_row3_col13,#T_a430a_row7_col2{
#             background-color:  #ead5c9;
#             color:  #000000;
#         }#T_a430a_row3_col15,#T_a430a_row11_col13,#T_a430a_row12_col4{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_a430a_row3_col16,#T_a430a_row16_col7{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_a430a_row4_col0,#T_a430a_row12_col9{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_a430a_row4_col1,#T_a430a_row8_col7,#T_a430a_row14_col4,#T_a430a_row14_col8{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_a430a_row4_col3,#T_a430a_row4_col15,#T_a430a_row13_col10{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_a430a_row4_col5,#T_a430a_row6_col14{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_a430a_row4_col8{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_a430a_row4_col9,#T_a430a_row16_col3{
#             background-c

# %% [markdown]
# Según la información que obtenemos de la matriz de correlación:
# PURCHASES y ONEOFF_PURCHASES tienen una muy alta correlación directa (0,9168).
# PURCHASES_FREQUENCY y PURCHASES_INSTALLMENTS_FREQUENCY tienen una alta correlación directa (0,8623).
# CASH_ADVANCE_FREQUENCY y CASH_ADVANCE_TRX tienen una alta correlación directa (0,7996).

# %% [markdown]
# **Distribución de la variable BALANCE**

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 5), dpi=300)
fig.suptitle('Distribución del saldo de las cuentas')

sns.boxplot(ax=axes[0],x=df["BALANCE"])
axes[0].set_xlabel('Balance')

# Charmander
sns.histplot(ax=axes[1],  x=df["BALANCE"],  palette='turbo')
axes[1].set_xlabel('Balance')
axes[1].set_xlabel('Número de clientes')
# Out:
# Text(0.5, 0, 'Número de clientes')

# %% [markdown]
# En la gráfica anterior comprobamos que los clientes de esta empresa de tarjetas de crédito no tienen, generalmente, mucho dinero en la cuenta. Esto quiere decir que esta empresa no está focalizada en clientes muy adinerados.

# %% [markdown]
# **Relación de la variable BALANCE con CREDIT_LIMIT**

# %%
df.TENURE.unique()
# Out:
# array([12,  8, 11,  9, 10,  6,  7], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10,3), dpi=300)


sns.barplot(data=df, x='TENURE', y='CREDIT_LIMIT',label='Credit Limit', color='lightblue')
sns.barplot(data=df, x='TENURE', y='BALANCE',label='Balance', color='b')

ax.legend()

# %% [markdown]
# En la gráfica anterior comprobamos que cuanto mayor es el número de tenure (permanencia de la tarjeta de crédito), mayor es el límite de la tarjeta de crédito y mayor es el balance (saldo de la cuenta). Por tanto, como es lógico, a mayor saldo en la cuenta, mayor límite de crédito de la tarjeta. Los clientes que tienen mayor saldo serán posiblemente los uqe mayores ingresos tengan y el banco les podrá otorgar más crédito ya que no tendrán mucho riesgo de hacer default.

# %%
fig, ax = plt.subplots(figsize=(10,4), dpi=300)

sns.scatterplot(data=df, x='BALANCE', y='CREDIT_LIMIT', palette='turbo', ax=ax)
plt.grid()

# %% [markdown]
# La correlación entre estas dos variables es directa pero no muy pronunciada.

# %%
fig, ax = plt.subplots(figsize=(7,4), dpi=300)

sns.scatterplot(data=df, x='BALANCE', y='PURCHASES', hue='CREDIT_LIMIT', palette='turbo', ax=ax)
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='PURCHASES'>

# %%
fig, ax = plt.subplots(figsize=(7,4), dpi=300)

sns.histplot(data=df, x='BALANCE', hue='TENURE',  palette='turbo', ax=ax)
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='Count'>
